# %% [markdown]
# <a href="https://colab.research.google.com/github/MubashirullahD/Tweets-Sentiment-Analysis/blob/master/Sentiment_Analysis_of_Tweets_using_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from keras import layers
from keras.layers import Input, Dense, Activation, Flatten
from keras.initializers import glorot_uniform
from keras.regularizers import l2
from keras.models import Model
from keras.utils import layer_utils
# Out:
# Using TensorFlow backend.

# %%
url = 'https://raw.githubusercontent.com/MubashirullahD/Tweets-Sentiment-Analysis/master/tweet_sentiment.csv'
df = pd.read_csv(url)
df.drop(df.columns[[0]], axis = 1, inplace = True)

# %%
features = df.drop(['Positive','Negative', 'Neutral'], axis = 1)
target  =  df.loc[:, ['Positive', 'Negative', 'Neutral']]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size = 0.3, random_state = 42,
                                                    stratify = target)

# %%
df
# Out:
#          0      1     2      3  ...    199  Positive  Negative  Neutral
# 0    False  False  True  False  ...  False       1.0       0.0      0.0
# 1     True  False  True   True  ...  False       1.0       0.0      0.0
# 2    False   True  True   True  ...  False       1.0       0.0      0.0
# 3     True  False  True  False  ...  False       0.0       0.0      1.0
# 4     True   True  True  False  ...  False       0.0       0.0      1.0
# ..     ...    ...   ...    ...  ...    ...       ...       ...      ...
# 337  False   True  True   True  ...   True       1.0       0.0      0.0
# 338   True   True  True  False  ...  False       1.0       0.0      0.0
# 339   True   True  True   True  ...  False       1.0       0.0      0.0
# 340   True   True  True   True  ...  False       1.0       0.0      0.0
# 341   True   True  True   True  ...  False       1.0       0.0      0.0
#
# [342 rows x 203 columns]

# %%
def SentimentModel(input_shape=(200,)):
    """
    Implementation of the SentimentModel.
    
    Arguments:
    input_shape -- shape of the tweets in the dataset

    Returns:
    model -- a Model() instance in Keras
    """
     
    X_input = Input(input_shape)
    
    X = Dense(15, activation='relu', kernel_regularizer=l2(0.01), name='fc1', kernel_initializer = glorot_uniform(seed=0))(X_input)
    
    X = Dense(3, activation='softmax', kernel_regularizer=l2(0.01), name='fc2', kernel_initializer = glorot_uniform(seed=0))(X)
    
    model = Model(inputs = X_input, outputs=X, name='SentimentModel')
    
    return model

# %%
SentimentModel = SentimentModel()

# %%
SentimentModel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["accuracy"])

# %%
SentimentModel.fit(x=X_train, y=Y_train, epochs=200, batch_size=32)
# Out:
# Epoch 1/200
# 239/239 [==============================] - 0s 1ms/step - loss: 1.2769 - accuracy: 0.5523
# Epoch 2/200
# 239/239 [==============================] - 0s 54us/step - loss: 1.2269 - accuracy: 0.5397
# Epoch 3/200
# 239/239 [==============================] - 0s 61us/step - loss: 1.1878 - accuracy: 0.5565
# Epoch 4/200
# 239/239 [==============================] - 0s 61us/step - loss: 1.1543 - accuracy: 0.5649
# Epoch 5/200
# 239/239 [==============================] - 0s 52us/step - loss: 1.1242 - accuracy: 0.5816
# Epoch 6/200
# 239/239 [==============================] - 0s 52us/step - loss: 1.0957 - accuracy: 0.5858
# Epoch 7/200
# 239/239 [==============================] - 0s 51us/step - loss: 1.0693 - accuracy: 0.5858
# Epoch 8/200
# 239/239 [==============================] - 0s 52us/step - loss: 1.0437 - accuracy: 0.5900
# Epoch 9/200
# 239/239 [==============================] - 0s 54us/step - loss: 1.0199 - accuracy: 0.6067
# Epoch 10/200
# ...

# %%
preds = SentimentModel.evaluate(x=X_test, y=Y_test)
### END CODE HERE ###
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 103/103 [==============================] - 0s 261us/step
#
# Loss = 1.4052035634957472
# Test Accuracy = 0.5048543810844421
